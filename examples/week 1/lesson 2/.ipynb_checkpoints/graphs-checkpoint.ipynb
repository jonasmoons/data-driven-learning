# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv("student_data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5bca45e26c64> in <module>()
# ----> 1 df = pd.read_csv("student_data.csv")
#
# NameError: name 'pd' is not defined
